# %%
#!conda install python-graphviz

# %%
import sys

# %%
sys.path
# Out:
# ['',
#  'C:\\Users\\Admin\\Anaconda3\\python36.zip',
#  'C:\\Users\\Admin\\Anaconda3\\DLLs',
#  'C:\\Users\\Admin\\Anaconda3\\lib',
#  'C:\\Users\\Admin\\Anaconda3',
#  'C:\\Users\\Admin\\Anaconda3\\lib\\site-packages',
#  'C:\\Users\\Admin\\Anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\Admin\\Anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\Admin\\Anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\Admin\\Anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\Admin\\.ipython']

# %%
sys.path.insert(0, 'C:\\Users\\Admin\\Anaconda3\\Library\\bin\\graphviz')
#sys.path.remove('C:\\Users\\Admin\\Anaconda3\\Library\\bin\\graphviz')

# %%
sys.path
# Out:
# ['C:\\Users\\Admin\\Anaconda3\\Library\\bin\\graphviz',
#  '',
#  'C:\\Users\\Admin\\Anaconda3\\python36.zip',
#  'C:\\Users\\Admin\\Anaconda3\\DLLs',
#  'C:\\Users\\Admin\\Anaconda3\\lib',
#  'C:\\Users\\Admin\\Anaconda3',
#  'C:\\Users\\Admin\\Anaconda3\\lib\\site-packages',
#  'C:\\Users\\Admin\\Anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\Admin\\Anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\Admin\\Anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\Admin\\Anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\Admin\\.ipython']

# %%
# !dot -V
# Out:
# dot - graphviz version 2.38.0 (20140413.2041)

# %%
from graphviz import Digraph

dot = Digraph(comment='The Round Table')

dot.node('A', 'King Arthur')
dot.node('B', 'Sir Bedevere the Wise')
dot.node('L', 'Sir Lancelot the Brave')

dot.edges(['AB', 'AL'])
dot.edge('B', 'L', constraint='false')

dot

# %%
import numpy as np
adjmatrix = np.array([[1, 2, 3], [0, 2, 0], [0, 3, 4]])
adjmatrix
# Out:
# array([[1, 2, 3],
#        [0, 2, 0],
#        [0, 3, 4]])

# %%
N = adjmatrix.shape[0]
M = adjmatrix.shape[1]

N, M
# Out:
# (3, 3)

# %%
from graphviz import Graph

g = Graph(comment='FromMatrix')


for i in range(N):
    g.node('Node'+str(i), 'Node'+str(i))
    for j in range(M):
        g.edge('Node'+str(i), 'Node'+str(j), label=str(adjmatrix[i][j]))
    
g
